# %% [markdown]
# # Exam - theory

# %% [markdown]
# ## Task 1
#
# Consider a system that is governed by the following equation
#
# $$\ddot{y}+2y + \sin y = u,$$
#
# where $u$ is the control input.
#
#
# Find fixed points of this system satisfying $y=\pi/2$ and linearize its dynamics around those fixed points.
#
# ## Task 2
#
# We have two identical pinhole cameras with focal lengths (both) 2 and optical centers (both) 200. Cameras have no distortions.
#
# * What is the camera matrix?
# * Let's assume two cameras' optic axes are parallel and the second camera is shifted by  x=1,y=0,z=0  with respect to the first camera. What is the pixel disparity (horizontal distance in pixels) between the points on images that correspond to a point in the 3D space with coordinates (5, 5, 5).

# %% [markdown]
# ## Task 3
#
# Robot has two prismatic joints with $d >= 0$. Robot base is located at $(0, 0, 0)$. Joints are connected by a link of length 1. Second joint is rotated around $X$ axis by 90 degrees as in an image below:
#
# When $d_0 = 1$ and $d_1 = 1$ location of end effector wrt base is $(0, 1, 2)$
#
# Find:
# - DH parameters
# - Forward kinematics transformation of end effector
# - Workspace of the robot (set of points achievable by end-effector).
# - Inverse kinematics equation in a closed form

# %% [markdown]
# ![egz-2.png](data:image/png;base64,...)

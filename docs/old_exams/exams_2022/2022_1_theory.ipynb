# %% [markdown]
# # Exam - theory

# %% [markdown]
# ## Task 1
#
# Assume there is a cell, which can be either occupied or empty. We have a prior knowledge that `prob(occupied)=0.3`.
#
# We are using a sensor, which we can model as follows:
# `prob(sensor=occupied | occupied) = 0.9`
# `prob(sensor=empty | empty) = 0.8`
#
# Assume we have three independent measurements with results `empty`, `empty`, `occupied`. Given the prior knowledge and the measurements compute the probability that the cell is occupied.

# %% [markdown]
# ## Task 2
#
# Find fixed points of the following system and linearize its dynamics around those fixed points (you can assume $-\pi \le \theta \le \pi$).
#
# $$\dot{r} = r^2-r$$
# $$\dot{\theta}=\sin^2(\theta/2)$$

# %% [markdown]
# ## Task 3
#
# We have two identical pinhole cameras with focal lengths (both) 1 and optical centers (both) 300.5. Cameras have no distortions.
#
# - What is the camera matrix?
# - What are 2D coordinates of mapping 3D point (10, 10, 5)?
# - Let's assume two cameras' optic axes are parallel and the second camera is shifted by $x=1, y=0, z=0$ with respect to the first camera. Estimate the distance from the first camera to the point that has coordinates $(303, 303)$ on the image taken by the first camera and $(298, 303)$ on the image taken by the second camera

# %% [markdown]
# ## Task 4
#
# Robot has two joints. First joint is revolute, second joint is prismatic with $d >= 0$. Robot base is located at $(0, 0, 0)$. Joints are connected by a link of length 1. Second joint is rotated around $Z$ axis by 90 degrees as in an image below:
#
# When $\theta_0 = 0$ and $d_1 = 1$ location of end effector wrt base is $(0, 1, 1)$
#
# Find:
# - DH parameters
# - Forward kinematics transformation of end effector
# - Workspace of the robot (set of points achievable by end-effector).
# - Inverse kinematics equation in a closed form

# %% [markdown]
# ![robot-kopia.png](data:image/png;base64,...)
